# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import os

from keras.layers import Dense, LSTM
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import load_model
from sklearn.model_selection import train_test_split as TTS

from matplotlib import animation

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(12)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 16, 10

# %%
def function(x):
    return math.sin(x)/x

# %%
X = np.linspace(-5,15,300)
y = np.array(list(map(function,X)))

# %%
plt.plot(X, y, label='Original data', color='#000000', linewidth=1.0)
plt.grid()
plt.title("Dataset")
plt.legend()
plt.show()

# %%
x_train, x_test, y_train, y_test = TTS(X, y, test_size=0.2, random_state=12)

# %%
x_train.shape, x_test.shape
# Out:
# ((240,), (60,))

# %%
x_train = x_train/10
x_test = x_test/10

# %%
model = Sequential()

model.add(Dense(10, input_dim=1, activation='selu', kernel_initializer='RandomNormal'))
model.add(Dense(10, activation='selu', kernel_initializer='RandomNormal'))
model.add(Dense(1, activation='linear'))

# %%
model.compile(loss='mse', optimizer=Op)

# %%
Op = Adam(lr=0.001)

# %%
hist = model.fit(x_train,y_train,batch_size=5,epochs=200,validation_data=(x_test,y_test))
# Out:
# Train on 240 samples, validate on 60 samples
# Epoch 1/200
# 240/240 [==============================] - 2s - loss: 0.1121 - val_loss: 0.1388
# Epoch 2/200
# 240/240 [==============================] - 1s - loss: 0.0764 - val_loss: 0.0836
# Epoch 3/200
# 240/240 [==============================] - 1s - loss: 0.0599 - val_loss: 0.0743
# Epoch 4/200
# 240/240 [==============================] - 1s - loss: 0.0548 - val_loss: 0.0549
# Epoch 5/200
# 240/240 [==============================] - 1s - loss: 0.0505 - val_loss: 0.0544
# Epoch 6/200
# 240/240 [==============================] - 1s - loss: 0.0455 - val_loss: 0.0458
# Epoch 7/200
# 240/240 [==============================] - 1s - loss: 0.0407 - val_loss: 0.0457
# Epoch 8/200
# 240/240 [==============================] - 1s - loss: 0.0370 - val_loss: 0.0373
# Epoch 9/200
# 240/240 [==============================] - 1s - loss: 0.0322 - val_loss: 0.0283
# Epoch 10/200
# ...

# %%
plt.plot(X, model.predict(X))
plt.plot(X, y, label='Original data', color='#000000', linewidth=1.0)
plt.grid()
plt.title("Predict vs original")
plt.legend()
plt.show()
